# %% [markdown]
# # RealSaS — IRIS Controlled V1 M256 Full-Matcher Gate
# Fresh 208 FIT + 48 TUNE, pilot64 excluded, D3-free full deterministic matcher. CAL/DEV/EXTERNAL remain sealed.

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd /content/drive/MyDrive/RealSaS_MASTER_CORPUS_1024_V3/reports/iris_controlled_v1
# !python run_iris_controlled_v1_m256.py --workers 4 --epochs 12

# %% [markdown]
# At completion inspect: `MyDrive/RealSaS_MASTER_CORPUS_1024_V3/runs/IRIS_CONTROLLED_V1_M256_V1/M256_DECISION.json`.
# Send the printed final JSON block back to ChatGPT.
